# %% [markdown]
# ### Will the Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaurant near where you are driving. Would you accept that coupon and take a short detour to the restaurant? Would you accept the coupon but use it on a subsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaurant? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under 20 USD), coffee houses, carry out & take away, bar, and more expensive restaurants ( 20 USD - 50 USD).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
data.isnull().sum() 
# print(len(data))
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
# Summary: drop car column altogether & drop na from other columns (Bar, CoffeeHouse, CarryAway, RestaurantLessThan20, Restaurant20To50)
## Justification
# car column has 12576 missing values; that is 99% of the data is missing.
# dropping the car column would be the right option due to two reasons
# reason-1: what type of car they drive is not a critical factor to the core analysis
# reason-2: populating the 99% data would introduce bias than insight
# for other columns, the number of na columns are negligible and dropping the na would be the right option.
data_cleaned = data.drop(columns=['car'])
data_cleaned = data_cleaned.dropna()
data_cleaned.isnull().sum()
# data_cleaned.head()
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
# Column "Y" is boolean and the mean() would give the acceptance rate
coupon_acceptance_rate = data_cleaned['Y'].mean()
# print(coupon_acceptance_rate)
# 56.93% drivers choose to accept the coupon
# hint: if the Y column has Yes or No, "coupon_acceptance_rate = (data_cleaned['Y'] == 'Yes').mean()" would give the same results
print(f"Propotion of drivers choose to accept the coupon is {coupon_acceptance_rate: .2%}")
# Out:
# Propotion of drivers choose to accept the coupon is  56.93%

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
data_cleaned['coupon'].value_counts().plot(kind='bar')
plt.title('Distributions of Coupon Types')
plt.xlabel('Coupon Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.set_theme(style='whitegrid')
sns.histplot(data=data_cleaned, x='temperature', color='steelblue')
plt.title('Distributions of Temperature')
plt.show()
# temperature column has only 3 distinct values; 30F, 55F, & 80F; being the reason for only three bars

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupons = data_cleaned[data_cleaned['coupon'] == 'Bar']
print(bar_coupons.shape)
# using double square bracket to get a dataFrame
# Out:
# (1913, 25)

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
bar_coupons_acceptance = bar_coupons['Y'].mean()
# print(bar_coupons_acceptance)
print(f"Propotion of bar coupon acceptance is {bar_coupons_acceptance: .2%}")
# Out:
# Propotion of bar coupon acceptance is  41.19%

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
# get the unique value from bar_coupons
# print([bar_coupons['Bar'].unique()])
# ['never', 'less1', '1~3', 'gt8', '4~8']

# to extract 3 or fewer times a month
fewer_visit_to_bar = bar_coupons[bar_coupons['Bar'].isin(['never', 'less1', '1~3'])]['Y'].mean()


# more than 3 times a month
more_visit_to_bar = bar_coupons[bar_coupons['Bar'].isin(['4~8', 'gt8'])]['Y'].mean()

print(f"Acceptance rate (3 or fewer visits): {fewer_visit_to_bar:.2%}")
print(f"Acceptance rate (more than 3 visits): {more_visit_to_bar:.2%}")
# Out:
# Acceptance rate (3 or fewer visits): 37.27%
# Acceptance rate (more than 3 visits): 76.17%

# %%
labels_q3 = ['3 or fewer visits/month', 'More than 3 visits/month']
rates_q3 = [fewer_visit_to_bar, more_visit_to_bar]

sns.barplot(x=labels_q3, y=rates_q3, hue=labels_q3, palette='Set2', legend=False)
plt.title('Bar Coupon Acceptance Rate by Visit Frequency')
plt.xlabel('Visit Frequency')
plt.ylabel('Acceptance Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
# Age is string column and converting to numeric
age_map = {
    'below21': 20,
    '21': 21,
    '26': 26,
    '31': 31,
    '36': 36,
    '41': 41,
    '46': 46,
    '50plus': 50
}
# create a new numberic column
bar_coupons['age_numeric'] = bar_coupons['age'].map(age_map)

over_25_bar_visitor = bar_coupons[
    (bar_coupons['age_numeric'] > 25) &
    (bar_coupons['Bar'].isin(['1~3', '4~8', 'gt8']))
]['Y'].mean()
# print(over_25_bar_visitor)
others = bar_coupons[
    ~((bar_coupons['age_numeric'] > 25) &
    (bar_coupons['Bar'].isin(['1~3', '4~8', 'gt8'])))
]['Y'].mean()

print(f"Sample population over 25yrs and go to bar more than once a month is {over_25_bar_visitor: .2%}")
print(f"all others are {others: .2%}")

# print(bar_coupons['age'])
# Out:
# Sample population over 25yrs and go to bar more than once a month is  68.98%
# all others are  33.77%

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
labels_q4 = ['Over 25 & frequent bar goers', 'All Others']
rates_q4 = [over_25_bar_visitor, others]

sns.barplot(x=labels_q4, y=rates_q4, hue=labels_q4, palette='Set2', legend=False)
plt.title('Bar Coupon Acceptance: Over 25 & Frequent vs All Others')
plt.xlabel('Driver Group')
plt.ylabel('Acceptance Rate')
plt.tight_layout()
plt.show()

# %%
unique_passanger = bar_coupons['passanger'].unique()
unique_occupation = bar_coupons['occupation'].unique()
print (unique_passanger)
print(unique_occupation)
# Out:
# <StringArray>
# ['Friend(s)', 'Alone', 'Kid(s)', 'Partner']
# Length: 4, dtype: str
# <StringArray>
# [               'Architecture & Engineering',
#                                    'Student',
#                 'Education&Training&Library',
#                                 'Unemployed',
#                         'Healthcare Support',
#       'Healthcare Practitioners & Technical',
#                            'Sales & Related',
#                                 'Management',
#   'Arts Design Entertainment Sports & Media',
#                    'Computer & Mathematical',
#               'Life Physical Social Science',
#                    'Personal Care & Service',
#            'Office & Administrative Support',
#                  'Construction & Extraction',
#                                      'Legal',
#                                    'Retired',
#                'Community & Social Services',
#          'Installation Maintenance & Repair',
# ...

# %%
group_bar_goers = bar_coupons[
    (bar_coupons['Bar'].isin(['1~3', '4~8', 'gt8'])) &
    (bar_coupons['passanger'] != 'Kid(s)') &
    (~bar_coupons['occupation'].isin(['Farming Fishing & Forestry']))
]['Y'].mean()
not_group_bar_goers = bar_coupons[
    ~((bar_coupons['Bar'].isin(['1~3', '4~8', 'gt8'])) &
    (bar_coupons['passanger'] != 'Kid(s)') &
    (~bar_coupons['occupation'].isin(['Farming Fishing & Forestry'])))
]['Y'].mean()
print(f"Frequent bar goers without kids and from non farming occupation are {group_bar_goers: .02%} and others are {not_group_bar_goers: .02%}")
# Out:
# Frequent bar goers without kids and from non farming occupation are  70.94% and others are  29.79%

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
maritalStatus = bar_coupons['maritalStatus'].unique()
income = bar_coupons['income'].unique()
RestaurantLessThan20 = bar_coupons['RestaurantLessThan20'].unique()
print(maritalStatus, income, RestaurantLessThan20)
# Out:
# <StringArray>
# ['Single', 'Married partner', 'Unmarried partner', 'Divorced', 'Widowed']
# Length: 5, dtype: str <StringArray>
# [ '$62500 - $74999',  '$12500 - $24999',  '$75000 - $87499',
#   '$50000 - $62499',  '$37500 - $49999',  '$25000 - $37499',
#   '$100000 or More',  '$87500 - $99999', 'Less than $12500']
# Length: 9, dtype: str <StringArray>
# ['4~8', '1~3', 'less1', 'gt8', 'never']
# Length: 5, dtype: str

# %%
# condition1 - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# condition2 - go to bars more than once a month and are under the age of 30 *OR*
# condition3 - go to cheap restaurants more than 4 times a month and income is less than 50K.

condition1 = (
    (bar_coupons['Bar'].isin(['1~3', '4~8', 'gt8'])) &
    (bar_coupons['passanger'] != 'Kid(s)') &
    (bar_coupons['maritalStatus'] != 'Widowed')
)

condition2 = (
    (bar_coupons['Bar'].isin(['1~3', '4~8', 'gt8'])) &
    (bar_coupons['age_numeric'] < 30)
)

condition3 = (
    (bar_coupons['RestaurantLessThan20'].isin(['4~8', 'gt8'])) &
    (bar_coupons['income'].isin(['Less than $12500', '$12500 - $24999', '$25000 - $37499', '$37500 - $49999']))
)

# %%
groups = ['Condition1: No kid, not widowed', 'Condition2: Under 30', 'Condition3: Cheap restaurant & low income', 'All Others']
rates = [
    bar_coupons[condition1]['Y'].mean(),
    bar_coupons[condition2]['Y'].mean(),
    bar_coupons[condition3]['Y'].mean(),
    bar_coupons[~(condition1 | condition2 | condition3)]['Y'].mean()
]

sns.barplot(x=groups, y=rates, hue=groups, palette='Set2', legend=False)
plt.title('Acceptance Rate by Driver Group')
plt.xlabel('Driver Group')
plt.ylabel('Acceptance Rate')
plt.xticks(rotation=15, ha='right')
plt.tight_layout()
plt.savefig('images/bar_acceptance_by_frequency.png', bbox_inches='tight')
plt.show()

# %%
# accepted vs rejected by visit frequency
bar_coupons['accepted'] = bar_coupons['Y'].map({1: 'Accepted', 0: 'Rejected'})
bar_freq_order = ['never', 'less1', '1~3', '4~8', 'gt8']

sns.countplot(data=bar_coupons, x='Bar', hue='accepted',
              order=bar_freq_order, palette='Set2')
plt.title('Bar Coupon: Accepted vs Rejected by Visit Frequency')
plt.xlabel('Monthly Visit Frequency')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig('images/bar_acceptance_vs_rejected.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# ### Hypothesize about drivers who accepted the bar coupons
#
#
# The Drivers who accept the car coupons tend to be frequent bar-goers; they visit more than once a month, who are between 26yrs to 50yrs old and travelling without kids and are not widowed.
#
# Frequent bar visits is the strongest predictor; that is, those who go more than 3 times a month accepts the coupons 76% vs infrequent goers at 37%
#
# Social context is the second most - drivers without kids and non-farming occupations accepted the coupons at 70.94% vs 29.79% for others.
#
# Budget conscious drivers also show higher acceptance
#
# **Summary**
#
# Overall, the ideal bar coupon recipient is a regular bar goer, travelling socially, without family obligations (like kids etc..)

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
# To explore other coupon groups, lets find the largest dataset
print(data_cleaned['coupon'].value_counts())
# Out:
# coupon
# Coffee House             3816
# Restaurant(<20)          2653
# Carry out & Take away    2280
# Bar                      1913
# Restaurant(20-50)        1417
# Name: count, dtype: int64

# %%
# coffee house is at top and lets explore the statistics for coffee guys
coffee_coupons = data_cleaned[data_cleaned['coupon'] == 'Coffee House']
print(coffee_coupons.shape)
# Out:
# (3816, 25)

# %%
coffee_coupon_acceptance_rate = coffee_coupons['Y'].mean()
print(f"Coffee House coupon acceptance rate is {coffee_coupon_acceptance_rate: .2%}")
# Out:
# Coffee House coupon acceptance rate is  49.63%

# %%
# like bar, lets use how frequent the drivers visit the coffee house in a given month
frequency_order = coffee_coupons['CoffeeHouse'].unique()
print(frequency_order)
frequency_order_sorted = ['never', 'less1', '1~3', '4~8', 'gt8']
# Out:
# <StringArray>
# ['less1', '4~8', '1~3', 'gt8', 'never']
# Length: 5, dtype: str

# %%
acceptance_by_freq = coffee_coupons.groupby('CoffeeHouse')['Y'].mean().reindex(frequency_order_sorted)

fig = px.bar(
    x=frequency_order_sorted,
    y=acceptance_by_freq.values,
    labels={'x': 'Monthly Visit Frequency', 'y': 'Acceptance Rate'},
    title='Coffee House Coupon Acceptance by Visit Frequency',
    color=frequency_order_sorted,
    color_discrete_sequence=px.colors.qualitative.Set2
)
fig.update_yaxes(tickformat='.0%')
fig.show()

# %% [markdown]
# Acceptance peaks at **10AM (~63%)**, aligning with the morning coffee habit, and remains moderate at **2PM (~54%)** for afternoon coffee breaks. Evening hours (6PM, 10PM) drop to ~41–43%, suggesting drivers are far less inclined toward coffee later in the day. This implies coupon delivery timing has a meaningful impact on acceptance — morning delivery is significantly more effective.

# %% [markdown]
# The side-by-side comparison makes the frequency effect visually clear. Drivers who **never** visit a coffee house are heavily skewed toward rejection, while the **1~3** and **4~8** frequency groups flip to more accepted than rejected. This reinforces that frequent visitors are the most valuable target audience for coffee house coupon campaigns.

# %% [markdown]
# The chart shows a clear upward trend — drivers who never visit a coffee house accept at only ~18%, while those who visit 4–8 times a month accept at ~68%. This mirrors the bar coupon finding: prior behavior is the strongest predictor of coupon acceptance. Frequent coffee house visitors already have the habit, making them far more receptive to the offer.

# %%
# lets use time of day
time_order = ['7AM', '10AM', '2PM', '6PM', '10PM']
acceptance_by_time = coffee_coupons.groupby('time')['Y'].mean().reindex(time_order)

fig = px.bar(
    x=time_order,
    y=acceptance_by_time.values,
    labels={'x': 'Time of Day', 'y': 'Acceptance Rate'},
    title='Coffee House Coupon Acceptance by Time of Day',
    color=time_order,
    color_discrete_sequence=px.colors.qualitative.Set2
)
fig.update_yaxes(tickformat='.0%')
fig.show()

# %%
# comparision chart for coffee coupons accepted vs rejected
coffee_coupons['accepted'] = coffee_coupons['Y'].map({1: 'Accepted', 0: 'Rejected'}) # making use of the map function
sns.countplot(data=coffee_coupons, x='CoffeeHouse', hue='accepted',
              order=frequency_order_sorted, palette='Set2')
plt.title('Coffee House Coupon: Accepted vs Rejected by Visit Frequency')
plt.xlabel('Monthly Visit Frequency')
plt.ylabel('Count')
plt.savefig('images/coffee_acceptance_vs_rejection.png', bbox_inches='tight')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Hypothesize about drivers who accepted the "Coffee House" coupons
#
#
# The overall acceptance rate for the coffee house coupon is 49.63% and primary factors are visit frequency and time of day
#
# **Summary**
#
# Overall, the ideal coffee house coupon recipient is a frequent coffee house visitor in the morning or early afternoon. Targetting the infrequent visitors pr evening drivers is less likely to yield better results.
